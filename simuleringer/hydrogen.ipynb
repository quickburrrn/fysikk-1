# %% [markdown]
# # Hydrogenet

# %%
print("hello world")

B = 2.18 * 10**-18
h = 6.63 * 10**-34

def e(n):
    return -B/n**2

def atto(n):
    return round(n * 10**18, 3)

def diff(n, m):
    return e(n) - e(m)

def tilfrekvens(energi):
    return energi/h

def frekvens_til_tolkning(frekvens):
    match frekvens:
        case (frekvens > 1)

print(f"{atto(e(1))} aj")
# Out:
# hello world
# -2.18 aj
